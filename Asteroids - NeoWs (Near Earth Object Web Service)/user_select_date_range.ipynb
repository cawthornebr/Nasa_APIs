# %% [markdown]
# # Look up NEO in date range

# %% [markdown]
# ### Import dependencies

# %%
import requests
from datetime import timedelta
import decimal

# Need to get to partent directory to import api info
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 

# Now that we have the parent directory, we import the api info
from nasak import nasak

# %% [markdown]
# ### User selects date range

# %%
# error handling for incorrect dates

# importing datetime
import datetime
from datetime import date

#set bool True
bool1 = True

#start while loop
while bool1 == True:
    
    #start user input date
    start_date = input("Enter start date (YYYY-MM-DD):")
    end_date = input("Enter end date (YYYY-MM-DD):")
    
    # see if the user date is in the correct datetime format and if not, have user try again until it's good
    try:
        
        start_date1 = datetime.datetime.strptime(start_date, '%Y-%m-%d')
        end_date1 = datetime.datetime.strptime(end_date, '%Y-%m-%d')
        
        #see if delta is greater than 7 day limit
        delta = end_date1 - start_date1
        if delta.days > 6:
            print("DATE ERROR - end date can only be 7 days after start_date.")
        else:
            bool1 = False
            break
            
    except ValueError:
        
        print("DATE FORMAT ERROR - please try again using the format YYYY-MM-DD")
# Out:
# Enter start date (YYYY-MM-DD):sdf
# Enter end date (YYYY-MM-DD):sdf
# DATE FORMAT ERROR - please try again using the format YYYY-MM-DD
# Enter start date (YYYY-MM-DD):2020-01-01
# Enter end date (YYYY-MM-DD):2020-01-08
# DATE ERROR - end date can only be 7 days after start_date.
# Enter start date (YYYY-MM-DD):2020-01-01
# Enter end date (YYYY-MM-DD):2020-01-08
# DATE ERROR - end date can only be 7 days after start_date.
# Enter start date (YYYY-MM-DD):2020-01-01
# Enter end date (YYYY-MM-DD):2020-01-07

# %% [markdown]
# ### Make API call and print results

# %%
# Save config information
url = 'https://api.nasa.gov/neo/rest/v1/feed?start_date='

# Build partial query URL
query_url = f'{url}{start_date}&end_date={end_date}&api_key={nasak}'

# make get query
response = requests.get(query_url).json()

neo = response['near_earth_objects']
loop_date = start_date1

# loop through each day
for day in range(delta.days+1):
    
    # change loop_date to string
    loop_date_str = loop_date.strftime("%Y-%m-%d")
    
    print("-----------------------")
    print(loop_date_str)
    print("-----------------------")
    
    # loop through each item in list for selected date
    for i in range(len(neo[loop_date_str])):
        print(f'---item {i+1} of {len(neo[loop_date_str])}---')
        print("name : " + neo[loop_date_str][i]['name'])
        print("id : " + neo[loop_date_str][i]['id'])
        missing_distance = round(decimal.Decimal(neo[loop_date_str][i]['close_approach_data'][0]['miss_distance']['miles']),2)
        print("missing distance : " + str(format(missing_distance, ",")) + " miles")
        print("jpl url : " + neo[loop_date_str][i]['nasa_jpl_url'])
    
    # take loop_date and add one day 
    loop_date = loop_date + timedelta(days=1)
# Out:
# -----------------------
# 2020-01-01
# -----------------------
# ---item 1 of 13---
# name : (2020 AN2)
# id : 3978225
# missing distance : 1,879,038.06 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3978225
# ---item 2 of 13---
# name : (2020 AX)
# id : 3972421
# missing distance : 4,615,830.42 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3972421
# ---item 3 of 13---
# name : (2019 WE5)
# id : 3893737
# missing distance : 12,511,611.91 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3893737
# ---item 4 of 13---
# name : (2020 AE2)
# id : 3976578
# missing distance : 22,044,209.38 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3976578
# ---item 5 of 13---
# name : (2011 YE40)
# id : 3591759
# missing distance : 5,980,021.53 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3591759
# ---item 6 of 13---
# name : (2013 EC20)
# id : 3630817
# missing distance : 15,059,610.28 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3630817
# ---item 7 of 13---
# name : (2016 EF195)
# id : 3747497
# missing distance : 25,862,032.79 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3747497
# ---item 8 of 13---
# name : (2011 HS60)
# id : 3564720
# missing distance : 18,486,924.13 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3564720
# ---item 9 of 13---
# name : (2020 AM1)
# id : 3976530
# missing distance : 14,841,047.70 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3976530
# ---item 10 of 13---
# name : (2020 AY1)
# id : 3976542
# missing distance : 1,967,507.47 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3976542
# ---item 11 of 13---
# name : (2019 YK)
# id : 3942362
# missing distance : 3,355,794.48 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3942362
# ---item 12 of 13---
# name : (2020 AP3)
# id : 3986685
# missing distance : 1,556,125.73 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3986685
# ---item 13 of 13---
# name : (2020 JU)
# id : 54016975
# missing distance : 12,185,126.55 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54016975
# -----------------------
# 2020-01-02
# -----------------------
# ---item 1 of 20---
# name : (2019 YO6)
# id : 3971141
# missing distance : 29,100,833.45 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3971141
# ---item 2 of 20---
# name : (2020 BK2)
# id : 3986810
# missing distance : 14,881,138.63 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3986810
# ---item 3 of 20---
# name : 416591 (2004 LC2)
# id : 2416591
# missing distance : 19,052,568.96 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2416591
# ---item 4 of 20---
# name : (2003 UW29)
# id : 3164418
# missing distance : 23,498,919.95 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3164418
# ---item 5 of 20---
# name : (2011 YP10)
# id : 3591616
# missing distance : 6,569,503.83 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3591616
# ---item 6 of 20---
# name : (2012 DN31)
# id : 3599868
# missing distance : 42,334,928.27 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3599868
# ---item 7 of 20---
# name : (2016 TR55)
# id : 3760885
# missing distance : 41,956,037.10 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3760885
# ---item 8 of 20---
# name : (2015 XZ168)
# id : 3736392
# missing distance : 42,056,452.67 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3736392
# ---item 9 of 20---
# name : 506491 (2003 UW29)
# id : 2506491
# missing distance : 23,498,944.59 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2506491
# ---item 10 of 20---
# name : (2013 AW52)
# id : 3623681
# missing distance : 16,978,739.24 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3623681
# ---item 11 of 20---
# name : (2019 AE3)
# id : 3837605
# missing distance : 1,158,396.13 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3837605
# ---item 12 of 20---
# name : (2015 DY53)
# id : 3711166
# missing distance : 17,984,393.31 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3711166
# ---item 13 of 20---
# name : (2019 YH2)
# id : 3943370
# missing distance : 1,757,463.29 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3943370
# ---item 14 of 20---
# name : (2020 AD)
# id : 3968763
# missing distance : 556,091.00 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3968763
# ---item 15 of 20---
# name : (2020 AC)
# id : 3968762
# missing distance : 804,692.76 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3968762
# ---item 16 of 20---
# name : (2020 BS5)
# id : 3989098
# missing distance : 20,886,547.28 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3989098
# ---item 17 of 20---
# name : (2020 AC1)
# id : 3973542
# missing distance : 495,749.20 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3973542
# ---item 18 of 20---
# name : (2020 AP1)
# id : 3976533
# missing distance : 203,083.40 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3976533
# ---item 19 of 20---
# name : (2019 YL6)
# id : 3971137
# missing distance : 4,747,432.78 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3971137
# ---item 20 of 20---
# name : (2020 KS2)
# id : 54017163
# missing distance : 39,707,193.58 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54017163
# -----------------------
# 2020-01-03
# -----------------------
# ---item 1 of 14---
# name : (2020 BD8)
# id : 3989183
# missing distance : 34,517,384.91 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3989183
# ---item 2 of 14---
# name : (2020 BN11)
# id : 3989261
# missing distance : 23,242,218.07 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3989261
# ---item 3 of 14---
# name : (2013 AB32)
# id : 3623610
# missing distance : 31,027,875.45 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3623610
# ---item 4 of 14---
# name : (2014 OY337)
# id : 3678563
# missing distance : 44,922,341.19 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3678563
# ---item 5 of 14---
# name : (2015 XR169)
# id : 3736409
# missing distance : 11,276,505.24 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3736409
# ---item 6 of 14---
# name : (2018 LH)
# id : 3825061
# missing distance : 36,599,261.05 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3825061
# ---item 7 of 14---
# name : (2013 AS27)
# id : 3623580
# missing distance : 23,441,406.67 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3623580
# ---item 8 of 14---
# name : (2015 XQ55)
# id : 3735998
# missing distance : 27,286,896.29 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3735998
# ---item 9 of 14---
# name : (2015 XF261)
# id : 3736497
# missing distance : 26,399,924.65 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3736497
# ---item 10 of 14---
# name : (2018 AU11)
# id : 3797676
# missing distance : 34,173,348.22 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3797676
# ---item 11 of 14---
# name : (2020 AP2)
# id : 3985565
# missing distance : 9,200,285.18 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3985565
# ---item 12 of 14---
# name : (2017 RV)
# id : 3781344
# missing distance : 8,035,776.59 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3781344
# ---item 13 of 14---
# name : (2019 YN4)
# id : 3959233
# missing distance : 33,364,683.53 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3959233
# ---item 14 of 14---
# name : (2020 BT2)
# id : 3986832
# missing distance : 6,013,049.33 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3986832
# -----------------------
# 2020-01-04
# -----------------------
# ---item 1 of 11---
# name : (2020 AM2)
# id : 3978224
# missing distance : 2,568,246.33 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3978224
# ---item 2 of 11---
# name : (2020 AU2)
# id : 3985570
# missing distance : 3,368,443.02 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3985570
# ---item 3 of 11---
# name : (2006 QA31)
# id : 3338518
# missing distance : 30,851,816.87 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3338518
# ---item 4 of 11---
# name : (2020 AQ2)
# id : 3985566
# missing distance : 5,509,714.67 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3985566
# ---item 5 of 11---
# name : (2008 LW16)
# id : 3414251
# missing distance : 10,553,780.02 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3414251
# ---item 6 of 11---
# name : (2014 AD17)
# id : 3655758
# missing distance : 26,903,204.88 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3655758
# ---item 7 of 11---
# name : (2019 QC6)
# id : 3843700
# missing distance : 44,985,748.78 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3843700
# ---item 8 of 11---
# name : 468541 (2006 QA31)
# id : 2468541
# missing distance : 30,851,800.87 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2468541
# ---item 9 of 11---
# name : (2004 RO111)
# id : 3252104
# missing distance : 31,904,422.55 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3252104
# ---item 10 of 11---
# name : (2019 YB4)
# id : 3959223
# missing distance : 780,195.86 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3959223
# ---item 11 of 11---
# name : (2020 AN1)
# id : 3976532
# missing distance : 614,176.84 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3976532
# -----------------------
# 2020-01-05
# -----------------------
# ---item 1 of 15---
# name : (2020 BE11)
# id : 3989254
# missing distance : 7,131,479.15 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3989254
# ---item 2 of 15---
# name : (2020 BH8)
# id : 3989187
# missing distance : 6,346,106.19 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3989187
# ---item 3 of 15---
# name : (2007 TE66)
# id : 3388355
# missing distance : 21,278,239.88 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3388355
# ---item 4 of 15---
# name : (2012 BU61)
# id : 3596491
# missing distance : 9,289,847.28 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3596491
# ---item 5 of 15---
# name : (2012 WH)
# id : 3618066
# missing distance : 37,826,402.82 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3618066
# ---item 6 of 15---
# name : (2019 OL3)
# id : 3843405
# missing distance : 34,843,296.89 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3843405
# ---item 7 of 15---
# name : (2017 YB2)
# id : 3794986
# missing distance : 26,647,966.86 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3794986
# ---item 8 of 15---
# name : (2019 AM8)
# id : 3837783
# missing distance : 26,866,008.16 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3837783
# ---item 9 of 15---
# name : 99942 Apophis (2004 MN4)
# id : 2099942
# missing distance : 41,616,790.52 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2099942
# ---item 10 of 15---
# name : (2015 YG)
# id : 3738544
# missing distance : 31,808,982.76 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3738544
# ---item 11 of 15---
# name : (2016 FA4)
# id : 3748278
# missing distance : 24,998,479.64 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3748278
# ---item 12 of 15---
# name : 538644 (2016 FA4)
# id : 2538644
# missing distance : 24,998,640.22 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2538644
# ---item 13 of 15---
# name : (2019 YM4)
# id : 3959232
# missing distance : 9,120,712.05 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3959232
# ---item 14 of 15---
# name : (2020 BM2)
# id : 3986812
# missing distance : 3,998,243.17 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3986812
# ---item 15 of 15---
# name : (2020 BU13)
# id : 3989305
# missing distance : 16,694,186.94 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3989305
# -----------------------
# 2020-01-06
# -----------------------
# ---item 1 of 9---
# name : (2019 YW)
# id : 3943322
# missing distance : 5,837,925.47 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3943322
# ---item 2 of 9---
# name : (2012 AB11)
# id : 3595775
# missing distance : 18,475,111.23 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3595775
# ---item 3 of 9---
# name : (2017 YQ5)
# id : 3795086
# missing distance : 12,042,934.58 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3795086
# ---item 4 of 9---
# name : (2015 FE37)
# id : 3714175
# missing distance : 31,064,359.08 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3714175
# ---item 5 of 9---
# name : (2019 NB5)
# id : 3843208
# missing distance : 45,730,689.94 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3843208
# ---item 6 of 9---
# name : (2020 BZ6)
# id : 3989159
# missing distance : 11,425,601.42 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3989159
# ---item 7 of 9---
# name : (2019 WD5)
# id : 3893736
# missing distance : 5,533,777.98 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3893736
# ---item 8 of 9---
# name : (2020 AW)
# id : 3972422
# missing distance : 1,137,046.47 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3972422
# ---item 9 of 9---
# name : (2020 AU1)
# id : 3976538
# missing distance : 987,050.01 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3976538
# -----------------------
# 2020-01-07
# -----------------------
# ---item 1 of 24---
# name : (2020 BJ3)
# id : 3986840
# missing distance : 9,692,925.82 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3986840
# ---item 2 of 24---
# name : (2019 QY4)
# id : 3843671
# missing distance : 33,381,687.72 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3843671
# ---item 3 of 24---
# name : (2006 WO3)
# id : 3359283
# missing distance : 38,598,039.86 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3359283
# ---item 4 of 24---
# name : (2009 AH16)
# id : 3444294
# missing distance : 31,180,736.18 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3444294
# ---item 5 of 24---
# name : (2020 BO3)
# id : 3986843
# missing distance : 14,997,511.94 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3986843
# ---item 6 of 24---
# name : (2020 BL1)
# id : 3986763
# missing distance : 2,776,474.07 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3986763
# ---item 7 of 24---
# name : (2015 YE18)
# id : 3739153
# missing distance : 40,152,080.74 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3739153
# ---item 8 of 24---
# name : (2016 NF22)
# id : 3755188
# missing distance : 16,981,432.49 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3755188
# ---item 9 of 24---
# name : (2019 YZ3)
# id : 3959221
# missing distance : 14,429,844.76 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3959221
# ---item 10 of 24---
# name : (2017 XU60)
# id : 3791344
# missing distance : 31,506,602.86 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3791344
# ---item 11 of 24---
# name : (2018 CA2)
# id : 3799271
# missing distance : 46,339,137.36 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3799271
# ---item 12 of 24---
# name : (2019 YT3)
# id : 3956452
# missing distance : 3,137,788.61 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3956452
# ---item 13 of 24---
# name : (2020 BV1)
# id : 3986773
# missing distance : 11,409,062.20 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3986773
# ---item 14 of 24---
# name : 481442 (2006 WO3)
# id : 2481442
# missing distance : 38,598,074.60 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2481442
# ---item 15 of 24---
# name : 512244 (2015 YE18)
# id : 2512244
# missing distance : 40,151,817.79 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2512244
# ---item 16 of 24---
# name : 281365 (2008 CM116)
# id : 2281365
# missing distance : 41,695,803.90 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2281365
# ---item 17 of 24---
# name : (2015 AJ44)
# id : 3703545
# missing distance : 26,150,329.62 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3703545
# ---item 18 of 24---
# name : (2013 CA88)
# id : 3626689
# missing distance : 6,653,770.08 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3626689
# ---item 19 of 24---
# name : (2019 KW)
# id : 3841977
# missing distance : 25,059,052.50 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3841977
# ---item 20 of 24---
# name : (2019 WH6)
# id : 3893768
# missing distance : 20,267,484.88 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3893768
# ---item 21 of 24---
# name : (2020 AJ1)
# id : 3973548
# missing distance : 3,225,488.67 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3973548
# ---item 22 of 24---
# name : (2020 AV1)
# id : 3976539
# missing distance : 1,729,568.41 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3976539
# ---item 23 of 24---
# name : (2020 AD3)
# id : 3986636
# missing distance : 7,979,262.68 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3986636
# ---item 24 of 24---
# name : (2019 WV4)
# id : 3893726
# missing distance : 9,514,500.87 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3893726

# %% [markdown]
# # Look-up specs based on ID

# %% [markdown]
# ### User enters ID

# %%
id_select = input("Enter ID: ")
# Out:
# Enter ID: 3978225

# %% [markdown]
# ### Set up query

# %%
# Save config information
url_id = 'https://api.nasa.gov/neo/rest/v1/neo/'

# Build partial query URL
query_url_id = f'{url_id}{id_select}?&api_key={nasak}'

# %% [markdown]
# ### Make API call

# %%
# make get query
response = requests.get(query_url_id).json()

print(response)
# Out:
# {'links': {'self': 'http://www.neowsapp.com/rest/v1/neo/3978225?api_key=3eMYRu2EnhR7Ch0G1uF5wEchDaMlFbOcXt5r793i'}, 'id': '3978225', 'neo_reference_id': '3978225', 'name': '(2020 AN2)', 'designation': '2020 AN2', 'nasa_jpl_url': 'http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3978225', 'absolute_magnitude_h': 26.5, 'estimated_diameter': {'kilometers': {'estimated_diameter_min': 0.0133215567, 'estimated_diameter_max': 0.0297879063}, 'meters': {'estimated_diameter_min': 13.3215566698, 'estimated_diameter_max': 29.7879062798}, 'miles': {'estimated_diameter_min': 0.008277629, 'estimated_diameter_max': 0.0185093411}, 'feet': {'estimated_diameter_min': 43.7058959846, 'estimated_diameter_max': 97.7293544391}}, 'is_potentially_hazardous_asteroid': False, 'close_approach_data': [{'close_approach_date': '2020-01-01', 'close_approach_date_full': '2020-Jan-01 21:18', 'epoch_date_close_approach': 1577913480000, 'relative_velocity': {'kilometers_per_second': '15.3528156363', 'kilometers_per_hour': '55270.1362905576', 'miles_per_hour': '34342.7132967634'}, 'miss_distance': {'astronomical': '0.0202143162', 'lunar': '7.8633690018', 'kilometers': '3024018.647026494', 'miles': '1879038.0551098572'}, 'orbiting_body': 'Earth'}], 'orbital_data': {'orbit_id': '1', 'orbit_determination_date': '2020-01-07 11:42:11', 'first_observation_date': '2020-01-06', 'last_observation_date': '2020-01-07', 'data_arc_in_days': 1, 'observations_used': 18, 'orbit_uncertainty': '9', 'minimum_orbit_intersection': '.00563207', 'jupiter_tisserand_invariant': '3.148', 'epoch_osculation': '2458855.5', 'eccentricity': '.6655600997875565', 'semi_major_axis': '2.449681643434989', 'inclination': '1.022832157339709', 'ascending_node_longitude': '259.8583225258365', 'orbital_period': '1400.434814303535', 'perihelion_distance': '.8192712843826523', 'perihelion_argument': '144.4984338580778', 'aphelion_distance': '4.080092002487326', 'perihelion_time': '2458813.681481417934', 'mean_anomaly': '10.74999459866381', 'mean_motion': '.2570630180877325', 'equinox': 'J2000', 'orbit_class': {'orbit_class_type': 'APO', 'orbit_class_description': 'Near-Earth asteroid orbits which cross the Earth’s orbit similar to that of 1862 Apollo', 'orbit_class_range': 'a (semi-major axis) > 1.0 AU; q (perihelion) < 1.017 AU'}}, 'is_sentry_object': False}
