# %%
import requests
from datetime import timedelta
# Need to get to partent directory to import api info
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 

# Now that we have the parent directory, we import the api info
from nasak import nasak

# %%
# error handling for incorrect dates

# importing datetime
import datetime
from datetime import date

#set bool True
bool1 = True

#start while loop
while bool1 == True:
    
    #start user input date
    start_date = input("Enter start date (YYYY-MM-DD):")
    end_date = input("Enter end date (YYYY-MM-DD):")
    
    # see if the user date is in the correct datetime format and if not, have user try again until it's good
    try:
        
        start_date1 = datetime.datetime.strptime(start_date, '%Y-%m-%d')
        end_date1 = datetime.datetime.strptime(end_date, '%Y-%m-%d')
        
        #see if delta is greater than 7 day limit
        delta = end_date1 - start_date1
        if delta.days > 6:
            print("DATE ERROR - end date can only be 7 days after start_date.")
        else:
            bool1 = False
            break
            
    except ValueError:
        
        print("DATE FORMAT ERROR - please try again using the format YYYY-MM-DD")
# Out:
# Enter start date (YYYY-MM-DD):20000101
# Enter end date (YYYY-MM-DD):20000102
# DATE FORMAT ERROR - please try again using the format YYYY-MM-DD
# Enter start date (YYYY-MM-DD):2000-01-01
# Enter end date (YYYY-MM-DD):2000-01-08
# DATE ERROR - end date can only be 7 days after start_date.
# Enter start date (YYYY-MM-DD):2001-01-01
# Enter end date (YYYY-MM-DD):2001-01-07

# %%
import decimal
# Save config information
url = 'https://api.nasa.gov/neo/rest/v1/feed?start_date='

# Build partial query URL
# query_url = f'{url}api_key={nasak}date={date}'
query_url = f'{url}{start_date}&end_date={end_date}&api_key={nasak}'

# make get query
response = requests.get(query_url).json()

neo = response['near_earth_objects']
loop_date = start_date1

# loop through each day
for day in range(delta.days+1):
    
    # change loop_date to string
    loop_date_str = loop_date.strftime("%Y-%m-%d")
    
    print("-----------------------")
    print(loop_date_str)
    print("-----------------------")
    
    # loop through each item in list for selected date
    for i in range(len(neo[loop_date_str])):
        print(f'---item {i+1} of {len(neo[loop_date_str])}---')
        print("name : " + neo[loop_date_str][i]['name'])
        print("id : " + neo[loop_date_str][i]['id'])
        missing_distance = round(decimal.Decimal(neo[loop_date_str][i]['close_approach_data'][0]['miss_distance']['miles']),2)
        print("missing distance : " + str(format(missing_distance, ",")) + " miles")
        print("jpl url : " + neo[loop_date_str][i]['nasa_jpl_url'])
    
    # take loop_date and add one day 
    loop_date = loop_date + timedelta(days=1)
# Out:
# -----------------------
# 2001-01-01
# -----------------------
# ---item 1 of 8---
# name : 162635 (2000 SS164)
# id : 2162635
# missing distance : 34,075,838.32 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2162635
# ---item 2 of 8---
# name : (2004 HF12)
# id : 3180152
# missing distance : 26,843,623.54 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3180152
# ---item 3 of 8---
# name : (2014 GE35)
# id : 3667127
# missing distance : 28,748,284.95 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3667127
# ---item 4 of 8---
# name : (2015 YE18)
# id : 3739153
# missing distance : 30,942,079.54 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3739153
# ---item 5 of 8---
# name : (2011 BZ59)
# id : 3557804
# missing distance : 30,657,076.73 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3557804
# ---item 6 of 8---
# name : 512244 (2015 YE18)
# id : 2512244
# missing distance : 30,943,305.07 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2512244
# ---item 7 of 8---
# name : 277475 (2005 WK4)
# id : 2277475
# missing distance : 38,175,881.35 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2277475
# ---item 8 of 8---
# name : (2012 BV13)
# id : 3596030
# missing distance : 15,806,354.09 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3596030
# -----------------------
# 2001-01-02
# -----------------------
# ---item 1 of 6---
# name : 20425 (1998 VD35)
# id : 2020425
# missing distance : 9,253,323.08 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2020425
# ---item 2 of 6---
# name : (2012 RO1)
# id : 3608427
# missing distance : 42,559,626.06 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3608427
# ---item 3 of 6---
# name : 7480 Norwan (1994 PC)
# id : 2007480
# missing distance : 46,003,365.75 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2007480
# ---item 4 of 6---
# name : 337345 (2001 KO20)
# id : 2337345
# missing distance : 25,805,698.89 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2337345
# ---item 5 of 6---
# name : (2013 XS3)
# id : 3654336
# missing distance : 44,802,790.97 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3654336
# ---item 6 of 6---
# name : (2020 GF1)
# id : 54016465
# missing distance : 28,787,831.01 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=54016465
# -----------------------
# 2001-01-03
# -----------------------
# ---item 1 of 12---
# name : 4688 (1980 WF)
# id : 2004688
# missing distance : 15,812,884.62 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2004688
# ---item 2 of 12---
# name : (2006 BV39)
# id : 3313974
# missing distance : 43,377,192.84 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3313974
# ---item 3 of 12---
# name : 452334 (2001 LB)
# id : 2452334
# missing distance : 25,439,455.00 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2452334
# ---item 4 of 12---
# name : (2000 YS134)
# id : 3067492
# missing distance : 6,200,855.15 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3067492
# ---item 5 of 12---
# name : (2007 NL1)
# id : 3379718
# missing distance : 26,706,074.56 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3379718
# ---item 6 of 12---
# name : (2016 BN1)
# id : 3740825
# missing distance : 40,027,170.42 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3740825
# ---item 7 of 12---
# name : 2100 Ra-Shalom (1978 RA)
# id : 2002100
# missing distance : 42,364,120.22 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2002100
# ---item 8 of 12---
# name : 3362 Khufu (1984 QA)
# id : 2003362
# missing distance : 20,213,601.64 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2003362
# ---item 9 of 12---
# name : 252558 (2001 WT1)
# id : 2252558
# missing distance : 43,968,660.55 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2252558
# ---item 10 of 12---
# name : (2009 LW2)
# id : 3463175
# missing distance : 6,272,561.01 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3463175
# ---item 11 of 12---
# name : (2011 OB)
# id : 3572706
# missing distance : 44,420,626.60 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3572706
# ---item 12 of 12---
# name : (2020 AN3)
# id : 3986682
# missing distance : 12,584,263.62 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3986682
# -----------------------
# 2001-01-04
# -----------------------
# ---item 1 of 4---
# name : (2011 CL50)
# id : 3557536
# missing distance : 1,561,864.15 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3557536
# ---item 2 of 4---
# name : (2017 YP1)
# id : 3794971
# missing distance : 41,367,807.72 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3794971
# ---item 3 of 4---
# name : 85182 (1991 AQ)
# id : 2085182
# missing distance : 36,780,711.35 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2085182
# ---item 4 of 4---
# name : (2007 WM3)
# id : 3395956
# missing distance : 11,975,330.01 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3395956
# -----------------------
# 2001-01-05
# -----------------------
# ---item 1 of 1---
# name : (2014 BF3)
# id : 3656918
# missing distance : 35,640,649.35 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3656918
# -----------------------
# 2001-01-06
# -----------------------
# ---item 1 of 2---
# name : (2016 YM)
# id : 3766065
# missing distance : 23,896,500.05 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3766065
# ---item 2 of 2---
# name : 88213 (2001 AF2)
# id : 2088213
# missing distance : 42,896,968.72 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2088213
# -----------------------
# 2001-01-07
# -----------------------
# ---item 1 of 8---
# name : 198752 (2005 EA60)
# id : 2198752
# missing distance : 37,772,671.06 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=2198752
# ---item 2 of 8---
# name : (2016 AF2)
# id : 3739154
# missing distance : 44,363,361.82 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3739154
# ---item 3 of 8---
# name : (2018 AN2)
# id : 3797456
# missing distance : 24,448,579.94 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3797456
# ---item 4 of 8---
# name : (2000 YT134)
# id : 3069224
# missing distance : 37,208,213.94 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3069224
# ---item 5 of 8---
# name : (2018 VK1)
# id : 3835974
# missing distance : 35,953,520.03 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3835974
# ---item 6 of 8---
# name : (2018 LC3)
# id : 3825138
# missing distance : 11,702,184.92 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3825138
# ---item 7 of 8---
# name : (2017 YU3)
# id : 3795026
# missing distance : 17,146,455.94 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3795026
# ---item 8 of 8---
# name : (2019 KN2)
# id : 3842597
# missing distance : 24,181,975.28 miles
# jpl url : http://ssd.jpl.nasa.gov/sbdb.cgi?sstr=3842597
