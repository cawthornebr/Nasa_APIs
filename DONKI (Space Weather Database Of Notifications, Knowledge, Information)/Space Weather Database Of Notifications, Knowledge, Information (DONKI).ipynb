# %% [markdown]
# ### Import dependencies

# %%
import requests
import json
# Need to get to partent directory to import api info
import os,sys,inspect
currentdir = os.path.dirname(os.path.abspath(inspect.getfile(inspect.currentframe())))
parentdir = os.path.dirname(currentdir)
sys.path.insert(0,parentdir) 

# Now that we have the parent directory, we import the api info
from nasak import nasak

# %% [markdown]
# # Set up date range

# %%
# ---Website peramiters---
# startDate: default to 30 days prior to current UTC date
# endDate: default to current UTC date
# Example:
# https://api.nasa.gov/DONKI/CME?startDate=yyyy-MM-dd&endDate=yyyy-MM-dd&api_key=DEMO_KEY
# ---Website peramiters---

# error handling for incorrect dates

# importing datetime
import datetime

# let user know of date limitation
print("You'll need to select a start and end date in the format of YYYY-MM-DD")

#set bool True
bool1 = True

#start while loop
while bool1 == True:
    
    #enter start date
    start_date = input("Enter Start Date (YYYY-MM-DD): ")
    
    #test start date to ensure it's a valid date
    try:
        datetime.datetime.strptime(start_date, '%Y-%m-%d')
        
        date1 = datetime.datetime.strptime(start_date, '%Y-%m-%d')
        
        bool1 = False
        
        break
            
    except ValueError:
        
        print("START DATE FORMAT ERROR - please try again using the format YYYY-MM-DD")

#set bool True
bool2 = True

#start while loop
while bool2 == True:
    
    #enter start date
    end_date = input("Enter End Date (YYYY-MM-DD): ")
    
    #test start date to ensure it's a valid date
    try:
        datetime.datetime.strptime(end_date, '%Y-%m-%d')
        
        date1 = datetime.datetime.strptime(end_date, '%Y-%m-%d')
        
        if end_date < start_date:
            
            print("End date can't be before start date. Please enter a valid end date.")
        else:
            bool2 = False
            break
            
    except ValueError:
        
        print("END DATE FORMAT ERROR - please try again using the format YYYY-MM-DD")
# Out:
# You'll need to select a start and end date in the format of YYYY-MM-DD
# Enter Start Date (YYYY-MM-DD): 2015-01-01
# Enter End Date (YYYY-MM-DD): 2015-12-01

# %% [markdown]
# # Coronal Mass Ejection (CME)

# %% [markdown]
# ### Prepare API call

# %%
# Save config information
url = 'https://api.nasa.gov/DONKI/CME?startDate='

# Build partial query URL
query_url = f'{url}{start_date}&endDate={end_date}&api_key={nasak}'

# %% [markdown]
# ### Make API call and format data

# %%
# make get query
try:
    response = requests.get(query_url).json()
    print(json.dumps(response, indent=4))
    
except ValueError:
    print("Date range selected has no results.")
# Out:
# [
#     {
#         "activityID": "2015-01-01T08:24:00-CME-001",
#         "catalog": "SWRC_CATALOG",
#         "startTime": "2015-01-01T08:24Z",
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/7509/-1",
#         "note": "Eruption visible in SDO 193, starting ~ 2014-12-31T17.00Z, extended area of post-eruption loops slowly appear NW of disk center around N30W20, eruption seems very slow, a complex, curved filament channel is involved.",
#         "instruments": [
#             {
#                 "id": 1,
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "id": 2,
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "cmeAnalyses": [
#             {
#                 "time21_5": "2015-01-01T23:14Z",
#                 "latitude": 31.0,
#                 "longitude": 26.0,
#                 "halfAngle": 32.0,
#                 "speed": 350.0,
#                 "type": "S",
#                 "isMostAccurate": true,
#                 "note": "using both SWPC_cat and STEREO_cat with approx. lat from SWPC_cat (which is also in approx. agreement of location of source region), CME very faint, only 3 images were fit in SWPC_cat, others were too noisy",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/7512/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2015-01-02T04:24Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": "2015-01-05T06:00Z",
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": true,
#                         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/7513/-1",
#                         "impactList": null,
#                         "cmeIDs": [
#                             "2015-01-01T08:24:00-CME-001"
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "time21_5": "2015-01-02T09:13Z",
#                 "latitude": 54.0,
#                 "longitude": 14.0,
#                 "halfAngle": 28.0,
#                 "speed": 144.0,
#                 "type": "S",
#                 "isMostAccurate": false,
#                 "note": "SWPC CAT analysis, very approximate",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/7510/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2015-01-02T14:36:00-CME-001",
#         "catalog": "SWRC_CATALOG",
#         "startTime": "2015-01-02T14:36Z",
#         "sourceLocation": "S07W40",
#         "activeRegionNum": null,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/7515/-1",
#         "note": "Associated with a very gradual eruption in a small AR NE from 2248 starting after the break of day. The source location is ~W40S7. The area of darkening is rather limited.",
#         "instruments": [
#             {
#                 "id": 1,
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "id": 2,
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "cmeAnalyses": [
#             {
#                 "time21_5": "2015-01-02T23:55Z",
#                 "latitude": 3.0,
#                 "longitude": 34.0,
#                 "halfAngle": 23.0,
#                 "speed": 353.0,
#                 "type": "S",
#                 "isMostAccurate": true,
#                 "note": "Reanalyzed with more C2 and STEREOA imagery",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/7519/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2015-01-03T08:14Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": "2015-01-06T00:00Z",
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": true,
#                         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/7518/-1",
#                         "impactList": null,
#                         "cmeIDs": [
#                             "2015-01-02T14:36:00-CME-001"
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "time21_5": "2015-01-02T22:42Z",
#                 "latitude": 4.0,
#                 "longitude": 43.0,
#                 "halfAngle": 23.0,
#                 "speed": 424.0,
#                 "type": "S",
#                 "isMostAccurate": false,
#                 "note": "",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/7516/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2015-01-02T20:46Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/7514/-1",
#                         "impactList": null,
#                         "cmeIDs": [
#                             "2015-01-02T14:36:00-CME-001"
#                         ]
#                     },
#                     {
#                         "modelCompletionTime": "2015-01-03T07:01Z",
#                         "au": 5.5,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/7520/-1",
#                         "impactList": null,
#                         "cmeIDs": [
#                             "2015-01-02T14:36:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2015-01-07T05:24:00-IPS-001"
#             }
#         ]
#     },
#     {
#         "activityID": "2015-01-03T03:24:00-CME-001",
#         "catalog": "SWRC_CATALOG",
#         "startTime": "2015-01-03T03:24Z",
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/7524/-1",
#         "note": "",
#         "instruments": [
#             {
#                 "id": 1,
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "id": 2,
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "cmeAnalyses": [
#             {
#                 "time21_5": "2015-01-03T23:40Z",
#                 "latitude": -49.0,
#                 "longitude": -82.0,
#                 "halfAngle": 42.0,
#                 "speed": 210.0,
#                 "type": "S",
#                 "isMostAccurate": true,
#                 "note": "Source region could not be found. It's possible that this CME might be associated with a small filament eruption occurring around 2015-01-02T21:48Z as seen in SDO AIA 304. However, the filament is extremely small and it's difficult to see whether it erupted or just left the field of view.",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/7525/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2015-01-06T18:24:00-CME-001",
#         "catalog": "SWRC_CATALOG",
#         "startTime": "2015-01-06T18:24Z",
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/7532/-1",
#         "note": "No source region could be found in SDO.",
#         "instruments": [
#             {
#                 "id": 1,
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "id": 2,
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "cmeAnalyses": [
#             {
#                 "time21_5": "2015-01-07T00:25Z",
#                 "latitude": 9.0,
#                 "longitude": 39.0,
#                 "halfAngle": 12.0,
#                 "speed": 532.0,
#                 "type": "C",
#                 "isMostAccurate": true,
#                 "note": "",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/7533/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2015-01-07T05:43Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/7534/-1",
#                         "impactList": null,
#                         "cmeIDs": [
#                             "2015-01-06T18:24:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2015-01-07T16:24:00-CME-001",
#         "catalog": "SWRC_CATALOG",
#         "startTime": "2015-01-07T16:24Z",
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/7545/-1",
#         "note": "SDO 193 shows indication of an eruption off the NE limb with its source behind the limb, starting ~20:00, EUVI A images support this (signature of an eruption between 14:48 and 19:50 at the NW close to the limb).",
#         "instruments": [
#             {
#                 "id": 1,
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "id": 2,
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "id": 5,
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "cmeAnalyses": [
#             {
#                 "time21_5": "2015-01-08T03:10Z",
#                 "latitude": 67.0,
#                 "longitude": -102.0,
#                 "halfAngle": 20.0,
#                 "speed": 579.0,
#                 "type": "C",
#                 "isMostAccurate": true,
#                 "note": "",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/7546/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2015-01-09T00:00:00-CME-001",
#         "catalog": "SWRC_CATALOG",
#         "startTime": "2015-01-09T00:00Z",
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/7548/-1",
#         "note": "There was this faintest CME in the SW, seen most clearly in STEREO A and very faint in C2 right after the break of day(midnight). Source location has not been determined with confidence. It could be activity (darkening) near AR2257 around 23:00 on the previous day (Karin also noticed post-eruption loops in the area). Calculation was made on this assumption using SWPC CAT, however the images don't fit so well and are faint.\n\nSWPC thinks it is a backsided CME, but no sign of source can be found in EUVI A imagery. \n\n~Anna",
#         "instruments": [
#             {
#                 "id": 1,
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "id": 2,
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "id": 5,
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "cmeAnalyses": [
#             {
#                 "time21_5": "2015-01-09T05:54Z",
#                 "latitude": -10.0,
#                 "longitude": 2.0,
#                 "halfAngle": 13.0,
#                 "speed": 265.0,
#                 "type": "S",
#                 "isMostAccurate": true,
#                 "note": "",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/7550/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2015-01-09T23:04Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": "2015-01-13T00:00Z",
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": true,
#                         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/7549/-1",
#                         "impactList": null,
#                         "cmeIDs": [
#                             "2015-01-09T00:00:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2015-01-10T05:06:00-CME-001",
#         "catalog": "SWRC_CATALOG",
#         "startTime": "2015-01-10T05:06Z",
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/7553/-1",
#         "note": "The source region of this CME was difficult to find. The eruption is believed to be associated with AR 2255.",
#         "instruments": [
#             {
#                 "id": 5,
#                 "displayName": "STEREO A: SECCHI/COR2"
#             },
#             {
#                 "id": 2,
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "cmeAnalyses": [
#             {
#                 "time21_5": "2015-01-10T07:45Z",
#                 "latitude": -19.0,
#                 "longitude": 31.0,
#                 "halfAngle": 16.0,
#                 "speed": 510.0,
#                 "type": "C",
#                 "isMostAccurate": true,
#                 "note": "",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/7554/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2015-01-10T15:02Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/7552/-1",
#                         "impactList": null,
#                         "cmeIDs": [
#                             "2015-01-10T05:06:00-CME-001"
#                         ]
#                     },
#                     {
#                         "modelCompletionTime": "2015-01-10T16:48Z",
#                         "au": 5.5,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/7555/-1",
#                         "impactList": null,
#                         "cmeIDs": [
#                             "2015-01-10T05:06:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2015-01-10T08:52:00-CME-001",
#         "catalog": "SWRC_CATALOG",
#         "startTime": "2015-01-10T08:52Z",
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/7556/-1",
#         "note": "Not modeled because of extremely narrow half-angle.",
#         "instruments": [
#             {
#                 "id": 1,
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "id": 2,
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "cmeAnalyses": [
#             {
#                 "time21_5": "2015-01-10T21:22Z",
#                 "latitude": 7.0,
#                 "longitude": -90.0,
#                 "halfAngle": 15.0,
#                 "speed": 260.0,
#                 "type": "S",
#                 "isMostAccurate": true,
#                 "note": "Re-measured because other measurements didn't seem realistic.  Plane of sky measurements because no additional information to indicate direction.",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/7565/-1",
#                 "enlilList": null
#             },
#             {
#                 "time21_5": "2015-01-10T14:32Z",
#                 "latitude": 1.0,
#                 "longitude": -36.0,
#                 "halfAngle": 10.0,
#                 "speed": 490.0,
#                 "type": "S",
#                 "isMostAccurate": false,
#                 "note": "",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/7557/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2015-01-10T13:42:00-CME-001",
#         "catalog": "SWRC_CATALOG",
#         "startTime": "2015-01-10T13:42Z",
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/7561/-1",
#         "note": "Source location is not clear. It is coming off of the east limb with high latitude.",
#         "instruments": [
#             {
#                 "id": 1,
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "id": 2,
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "cmeAnalyses": null,
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2015-01-11T00:00:00-CME-001",
#         "catalog": "SWRC_CATALOG",
#         "startTime": "2015-01-11T00:00Z",
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/7559/-1",
#         "note": "Bright but slow NE CME.  No clear source location found but believed to be a near limb event.  High northern latitude so it is not expected to be significant.",
#         "instruments": [
#             {
#                 "id": 1,
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "id": 2,
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "id": 5,
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "cmeAnalyses": [
#             {
#                 "time21_5": "2015-01-11T16:15Z",
#                 "latitude": 59.0,
#                 "longitude": -100.0,
#                 "halfAngle": 30.0,
#                 "speed": 200.0,
#                 "type": "S",
#                 "isMostAccurate": true,
#                 "note": "Slow, high northern latitude CME.",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/7560/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2015-01-11T16:48:00-CME-001",
#         "catalog": "SWRC_CATALOG",
#         "startTime": "2015-01-11T16:48Z",
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/7570/-1",
#         "note": "No clear source, CME was faint and high-latitude.",
#         "instruments": [
#             {
#                 "id": 1,
#                 "displayName": "SOHO: LASCO/C2"
#             }
#         ],
#         "cmeAnalyses": [
#             {
#                 "time21_5": "2015-01-12T07:18Z",
#                 "latitude": 72.0,
#                 "longitude": -90.0,
#                 "halfAngle": 15.0,
#                 "speed": 250.0,
#                 "type": "S",
#                 "isMostAccurate": true,
#                 "note": "Measurements are plane of sky only - not enough information to infer direction, but CME was very close to north pole.",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/7571/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2015-01-11T21:46:00-CME-001",
#         "catalog": "SWRC_CATALOG",
#         "startTime": "2015-01-11T21:46Z",
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/7563/-1",
#         "note": "High-latitude CME with no clear source region.  This CME is similar to the 2015-01-11T16:48Z CME.",
#         "instruments": [
#             {
#                 "id": 1,
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "id": 2,
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "id": 5,
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "cmeAnalyses": [
#             {
#                 "time21_5": "2015-01-12T04:38Z",
#                 "latitude": 73.0,
#                 "longitude": -90.0,
#                 "halfAngle": 15.0,
#                 "speed": 480.0,
#                 "type": "S",
#                 "isMostAccurate": true,
#                 "note": "CME measurements are plane of sky, CME was narrow, bright and high-latitude.  Propagated non-radially so was difficult to triangulate.",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/7566/-1",
#                 "enlilList": null
#             },
#             {
#                 "time21_5": "2015-01-12T03:15Z",
#                 "latitude": 40.0,
#                 "longitude": -15.0,
#                 "halfAngle": 18.0,
#                 "speed": 500.0,
#                 "type": "C",
#                 "isMostAccurate": false,
#                 "note": "",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/7564/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2015-01-12T05:03Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/7567/-1",
#                         "impactList": null,
#                         "cmeIDs": [
#                             "2015-01-11T21:46:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2015-01-11T23:12:00-CME-001",
#         "catalog": "SWRC_CATALOG",
#         "startTime": "2015-01-11T23:12Z",
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/7568/-1",
#         "note": "There was a flare from AR2260 (N10W28) around 22:15UT, didn't appear to have a CME but there was a large wave transient launched towards the NE at the right time.  However, it's tough to tell for sure. This CME looks very similar to the 16:48Z and 21:46Z CMEs, so they might have similar sources.",
#         "instruments": [
#             {
#                 "id": 1,
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "id": 2,
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "cmeAnalyses": [
#             {
#                 "time21_5": "2015-01-12T03:54Z",
#                 "latitude": 74.0,
#                 "longitude": -90.0,
#                 "halfAngle": 17.0,
#                 "speed": 690.0,
#                 "type": "C",
#                 "isMostAccurate": true,
#                 "note": "This measurement is plane of sky because it's tough to tell the direction - CME was very bright and narrow, so it probably came from close to the limb.  Longitude is set to -90 just for plane of sky purposes.",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/7569/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2015-01-12T01:25:00-CME-001",
#         "catalog": "SWRC_CATALOG",
#         "startTime": "2015-01-12T01:25Z",
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/7572/-1",
#         "note": "No clear source - could be associated with the flare and maybe eruption starting around 23:15UT from AR 2206 (located at N10W28).",
#         "instruments": [
#             {
#                 "id": 1,
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "id": 2,
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "cmeAnalyses": [
#             {
#                 "time21_5": "2015-01-12T10:09Z",
#                 "latitude": 15.0,
#                 "longitude": 90.0,
#                 "halfAngle": 21.0,
#                 "speed": 390.0,
#                 "type": "S",
#                 "isMostAccurate": true,
#                 "note": "Measurement is plane of sky only.",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/7573/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2015-01-12T13:36:00-CME-001",
#         "catalog": "SWRC_CATALOG",
#         "startTime": "2015-01-12T13:36Z",
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/7574/-1",
#         "note": "Another north pole CME similar to the 2015-01-11T16:48Z, 21:46Z and 23:12Z CMEs.  No clear source region again.",
#         "instruments": [
#             {
#                 "id": 1,
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "id": 2,
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "cmeAnalyses": [
#             {
#                 "time21_5": "2015-01-12T20:26Z",
#                 "latitude": 81.0,
#                 "longitude": -90.0,
#                 "halfAngle": 14.0,
#                 "speed": 510.0,
#                 "type": "C",
#                 "isMostAccurate": true,
#                 "note": "CME was non-radial.  First appeared to the west of the north pole, but final trajectory was slightly to the east.",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/7575/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2015-01-12T15:36:00-CME-001",
#         "catalog": "SWRC_CATALOG",
#         "startTime": "2015-01-12T15:36Z",
#         "sourceLocation": "S10E40",
#         "activeRegionNum": 12261,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/7576/-1",
#         "note": "Two-ribbon flare, dimming and prominence eruption from AR 2261 viewed in AIA 193A images starting around 15:10 UT.",
#         "instruments": [
#             {
#                 "id": 1,
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "id": 2,
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "cmeAnalyses": [
#             {
#                 "time21_5": "2015-01-12T18:39Z",
#                 "latitude": 3.0,
#                 "longitude": -45.0,
#                 "halfAngle": 27.0,
#                 "speed": 880.0,
#                 "type": "C",
#                 "isMostAccurate": true,
#                 "note": "Longitude of CME is based on assumed source region.  The speed listed is the asymptotic speed approaching 21.5 RSun - it was going over 1200 km/sec in the beginning.  There is probably more of a southward extension of the CME, hard to see behind the C3 occulter.",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/7577/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2015-01-12T21:06Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": "2015-01-15T08:00Z",
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": true,
#                         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/7580/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "MESSENGER",
#                                 "arrivalTime": "2015-01-13T10:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Spitzer",
#                                 "arrivalTime": "2015-01-15T00:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2015-01-12T15:36:00-CME-001",
#                             "2015-01-12T16:57:00-CME-001"
#                         ]
#                     },
#                     {
#                         "modelCompletionTime": "2015-01-12T22:49Z",
#                         "au": 5.5,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/7581/-1",
#                         "impactList": null,
#                         "cmeIDs": [
#                             "2015-01-12T15:36:00-CME-001",
#                             "2015-01-12T16:57:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2015-01-15T22:39:00-IPS-001"
#             }
#         ]
#     },
#     {
#         "activityID": "2015-01-12T16:57:00-CME-001",
#         "catalog": "SWRC_CATALOG",
#         "startTime": "2015-01-12T16:57Z",
#         "sourceLocation": "S15W55",
#         "activeRegionNum": 12255,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/7578/-1",
#         "note": "There are two possible source regions: C7.0 flare + dimming from AR 2255  from 13:55 UT - 15:40 UT in the AIA 193\u00c5 images.  There was also a flare and possible CME from an AR SE of disk center in the STEREO-A EUVI 195 images from 15:39 - 16:09 UT.   The measurements are based on the assumption that the first source region is correct.",
#         "instruments": [
#             {
#                 "id": 1,
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "id": 2,
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "cmeAnalyses": [
#             {
#                 "time21_5": "2015-01-13T02:28Z",
#                 "latitude": 13.0,
#                 "longitude": 55.0,
#                 "halfAngle": 27.0,
#                 "speed": 350.0,
#                 "type": "S",
#                 "isMostAccurate": true,
#                 "note": "CME was a lopsided shape, with a fainter leading edge and a brighter interior front. Measurements are of the outer, fainter front.",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/7579/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2015-01-12T21:06Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": "2015-01-15T08:00Z",
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": true,
#                         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/7580/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "MESSENGER",
#                                 "arrivalTime": "2015-01-13T10:00Z"
#                             },
#                             {
#                                 "isGlancingBlow": true,
#                                 "location": "Spitzer",
#                                 "arrivalTime": "2015-01-15T00:00Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2015-01-12T15:36:00-CME-001",
#                             "2015-01-12T16:57:00-CME-001"
#                         ]
#                     },
#                     {
#                         "modelCompletionTime": "2015-01-12T22:49Z",
#                         "au": 5.5,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/7581/-1",
#                         "impactList": null,
#                         "cmeIDs": [
#                             "2015-01-12T15:36:00-CME-001",
#                             "2015-01-12T16:57:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2015-01-15T22:39:00-IPS-001"
#             }
#         ]
#     },
#     {
#         "activityID": "2015-01-13T05:24:00-CME-001",
#         "catalog": "SWRC_CATALOG",
#         "startTime": "2015-01-13T05:24Z",
#         "sourceLocation": "N07W70",
#         "activeRegionNum": 12257,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/7590/-1",
#         "note": "The source is opening field lines above the flaring active region.  CME was very narrow.",
#         "instruments": [
#             {
#                 "id": 1,
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "id": 2,
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "cmeAnalyses": [
#             {
#                 "time21_5": "2015-01-13T11:50Z",
#                 "latitude": 25.0,
#                 "longitude": 70.0,
#                 "halfAngle": 7.0,
#                 "speed": 560.0,
#                 "type": "C",
#                 "isMostAccurate": true,
#                 "note": "CME was very narrow, assumed 3D direction was based on flaring location.",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/7591/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2015-01-13T04:13:00-FLR-001"
#             }
#         ]
#     },
#     {
#         "activityID": "2015-01-13T13:25:00-CME-001",
#         "catalog": "SWRC_CATALOG",
#         "startTime": "2015-01-13T13:25Z",
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/7594/-1",
#         "note": "Another ragged CME similar to the 2015-01-11T16:48Z, 21:46Z, 23:12Z, and 2015-01-12T13:36:00 CMEs.   Source looks like it may be a brightening loop region close to the north pole.",
#         "instruments": [
#             {
#                 "id": 1,
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "id": 2,
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "cmeAnalyses": [
#             {
#                 "time21_5": "2015-01-13T21:00Z",
#                 "latitude": 88.0,
#                 "longitude": 90.0,
#                 "halfAngle": 24.0,
#                 "speed": 475.0,
#                 "type": "S",
#                 "isMostAccurate": true,
#                 "note": "Plane of sky measurements (CME was probably close to the plane of the sky).",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/7595/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2015-01-13T15:24:00-CME-001",
#         "catalog": "SWRC_CATALOG",
#         "startTime": "2015-01-13T15:24Z",
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/7592/-1",
#         "note": "A faint but distinct halo-like CME. No clear source region - the CME had the shape and projection of an eruption that was far out of the plane of the sky. The assumption is that the source was from the far side, but there were no STEREO EUVI images to confirm this.",
#         "instruments": [
#             {
#                 "id": 1,
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "id": 2,
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "cmeAnalyses": [
#             {
#                 "time21_5": "2015-01-13T20:53Z",
#                 "latitude": 26.0,
#                 "longitude": 135.0,
#                 "halfAngle": 45.0,
#                 "speed": 600.0,
#                 "type": "C",
#                 "isMostAccurate": true,
#                 "note": "This was faint, broad halo-type covering the NW limb of the Sun.   The latitude is based on a guess that the CME was 45 degrees out of the plane of the sky.",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/7593/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2015-01-14T04:50Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/7597/-1",
#                         "impactList": null,
#                         "cmeIDs": [
#                             "2015-01-13T15:24:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2015-01-13T18:00:00-CME-001",
#         "catalog": "SWRC_CATALOG",
#         "startTime": "2015-01-13T18:00Z",
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/7600/-1",
#         "note": "These are very very approximate parameters. Location is based on SDO EUV reconfiguration seen in the northeastern quadrant around the time of the CME. Speed based on STEREO CAT with plane of sky adjustment. SWPC_CAT was not useful at all for this event. Anyhow, the event will most likely not have any space weather consequences.",
#         "instruments": [
#             {
#                 "id": 1,
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "id": 2,
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "cmeAnalyses": [
#             {
#                 "time21_5": "2015-01-14T18:45Z",
#                 "latitude": 45.0,
#                 "longitude": -45.0,
#                 "halfAngle": 25.0,
#                 "speed": 300.0,
#                 "type": "S",
#                 "isMostAccurate": true,
#                 "note": "These are very very approximate parameters. Location is based on SDO EUV reconfiguration seen in the northeastern quadrant around the time of the CME. Speed based on STEREO CAT with plane of sky adjustment. SWPC_CAT was not useful at all for this event. Anyhow, the event will most likely not have any space weather consequences.",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/7601/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2015-01-14T16:36:00-CME-001",
#         "catalog": "SWRC_CATALOG",
#         "startTime": "2015-01-14T16:36Z",
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/7605/-1",
#         "note": "Parameters are very rough since CME is very faint and difficult to measure.",
#         "instruments": [
#             {
#                 "id": 1,
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "id": 2,
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "id": 5,
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "cmeAnalyses": [
#             {
#                 "time21_5": "2015-01-15T05:13Z",
#                 "latitude": 35.0,
#                 "longitude": 85.0,
#                 "halfAngle": 20.0,
#                 "speed": 257.0,
#                 "type": "S",
#                 "isMostAccurate": true,
#                 "note": "",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/7606/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2015-01-15T04:24:00-CME-001",
#         "catalog": "SWRC_CATALOG",
#         "startTime": "2015-01-15T04:24Z",
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/7607/-1",
#         "note": "CME associated with a filament eruption observed in SDO 304 around  04UT.  Parameters are very preliminary due to data gaps in SOHO LASCO imagery.",
#         "instruments": [
#             {
#                 "id": 1,
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "id": 2,
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "cmeAnalyses": [
#             {
#                 "time21_5": "2015-01-15T20:24Z",
#                 "latitude": 44.0,
#                 "longitude": -27.0,
#                 "halfAngle": 32.0,
#                 "speed": 193.0,
#                 "type": "S",
#                 "isMostAccurate": true,
#                 "note": "",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/7608/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2015-01-15T15:36:00-CME-001",
#         "catalog": "SWRC_CATALOG",
#         "startTime": "2015-01-15T15:36Z",
#         "sourceLocation": "N30E10",
#         "activeRegionNum": null,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/7609/-1",
#         "note": "CME associated with a NE eruption visible on SDO 304 and 193 around 15UT.  Loops seem like moving northward of the source region.",
#         "instruments": [
#             {
#                 "id": 1,
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "id": 2,
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "cmeAnalyses": [
#             {
#                 "time21_5": "2015-01-16T01:18Z",
#                 "latitude": 43.0,
#                 "longitude": -12.0,
#                 "halfAngle": 20.0,
#                 "speed": 363.0,
#                 "type": "S",
#                 "isMostAccurate": true,
#                 "note": "using STEREO_cat with approximate source location from SDO, parameters measured quite close to disk, should be remeasured when updated images are available.",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/7612/-1",
#                 "enlilList": null
#             },
#             {
#                 "time21_5": "2015-01-16T03:25Z",
#                 "latitude": 46.0,
#                 "longitude": -10.0,
#                 "halfAngle": 31.0,
#                 "speed": 277.0,
#                 "type": "S",
#                 "isMostAccurate": false,
#                 "note": "",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/7610/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2015-01-16T05:36:00-CME-001",
#         "catalog": "SWRC_CATALOG",
#         "startTime": "2015-01-16T05:36Z",
#         "sourceLocation": "N09W81",
#         "activeRegionNum": null,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/7613/-1",
#         "note": "CME could be associated with an eruption visible near AR 2260 around 04:55Z.  CME is narrow and measurements are preliminary.",
#         "instruments": [
#             {
#                 "id": 1,
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "id": 2,
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "cmeAnalyses": [
#             {
#                 "time21_5": "2015-01-16T16:20Z",
#                 "latitude": 62.0,
#                 "longitude": 78.0,
#                 "halfAngle": 20.0,
#                 "speed": 271.0,
# ...
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "cmeAnalyses": [
#             {
#                 "time21_5": "2015-11-28T07:47Z",
#                 "latitude": 20.0,
#                 "longitude": -160.0,
#                 "halfAngle": 28.0,
#                 "speed": 322.0,
#                 "type": "S",
#                 "isMostAccurate": true,
#                 "note": "",
#                 "levelOfData": 1,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/9761/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2015-11-28T20:40Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/9760/-1",
#                         "impactList": null,
#                         "cmeIDs": [
#                             "2015-11-28T04:00:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2015-11-28T13:25:00-CME-001",
#         "catalog": "SWRC_CATALOG",
#         "startTime": "2015-11-28T13:25Z",
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/9766/-1",
#         "note": "Source is not quite clear.  It could be associated with a disturbed filament seen on the SE liimb in SDO 171.",
#         "instruments": [
#             {
#                 "id": 1,
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "id": 2,
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "id": 5,
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "cmeAnalyses": [
#             {
#                 "time21_5": "2015-11-29T07:49Z",
#                 "latitude": -38.0,
#                 "longitude": -97.0,
#                 "halfAngle": 29.0,
#                 "speed": 547.0,
#                 "type": "C",
#                 "isMostAccurate": true,
#                 "note": "",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/9776/-1",
#                 "enlilList": null
#             },
#             {
#                 "time21_5": "2015-11-29T06:40Z",
#                 "latitude": -30.0,
#                 "longitude": -131.0,
#                 "halfAngle": 27.0,
#                 "speed": 554.0,
#                 "type": "C",
#                 "isMostAccurate": false,
#                 "note": "",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/9775/-1",
#                 "enlilList": null
#             },
#             {
#                 "time21_5": "2015-11-29T10:51Z",
#                 "latitude": -34.0,
#                 "longitude": -63.0,
#                 "halfAngle": 33.0,
#                 "speed": 200.0,
#                 "type": "S",
#                 "isMostAccurate": false,
#                 "note": "",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/9767/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2015-11-29T07:36:00-CME-001",
#         "catalog": "SWRC_CATALOG",
#         "startTime": "2015-11-29T07:36Z",
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/9763/-1",
#         "note": "Source appears to be back-sided. Eruption can be seen in the center of the disc in STA EUVI imagery.",
#         "instruments": [
#             {
#                 "id": 1,
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "id": 2,
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "id": 5,
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "cmeAnalyses": [
#             {
#                 "time21_5": "2015-11-29T13:01Z",
#                 "latitude": -3.0,
#                 "longitude": -160.0,
#                 "halfAngle": 44.0,
#                 "speed": 770.0,
#                 "type": "C",
#                 "isMostAccurate": true,
#                 "note": "New parameters using SOHO C2, C3, and STA imagery.",
#                 "levelOfData": 1,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/9770/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2015-11-29T18:21Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/9769/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "STEREO A",
#                                 "arrivalTime": "2015-12-01T16:40Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "STEREO B",
#                                 "arrivalTime": "2015-12-01T23:49Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2015-11-29T07:36:00-CME-001"
#                         ]
#                     },
#                     {
#                         "modelCompletionTime": "2015-11-29T19:21Z",
#                         "au": 5.5,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/9771/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "STEREO A",
#                                 "arrivalTime": "2015-12-01T16:23Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "STEREO B",
#                                 "arrivalTime": "2015-12-01T23:35Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2015-11-29T07:36:00-CME-001"
#                         ]
#                     }
#                 ]
#             },
#             {
#                 "time21_5": "2015-11-29T11:59Z",
#                 "latitude": -3.0,
#                 "longitude": -160.0,
#                 "halfAngle": 44.0,
#                 "speed": 770.0,
#                 "type": "C",
#                 "isMostAccurate": false,
#                 "note": "",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/9768/-1",
#                 "enlilList": null
#             },
#             {
#                 "time21_5": "2015-11-29T13:01Z",
#                 "latitude": -9.0,
#                 "longitude": -158.0,
#                 "halfAngle": 45.0,
#                 "speed": 637.0,
#                 "type": "C",
#                 "isMostAccurate": false,
#                 "note": "Measurement taken using only STA imagery.",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/9764/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2015-11-29T14:44Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/9765/-1",
#                         "impactList": [
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "STEREO A",
#                                 "arrivalTime": "2015-12-01T21:59Z"
#                             },
#                             {
#                                 "isGlancingBlow": false,
#                                 "location": "STEREO B",
#                                 "arrivalTime": "2015-12-02T05:02Z"
#                             }
#                         ],
#                         "cmeIDs": [
#                             "2015-11-29T07:36:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2015-12-02T12:30:00-IPS-001"
#             }
#         ]
#     },
#     {
#         "activityID": "2015-11-30T03:09:00-CME-001",
#         "catalog": "SWRC_CATALOG",
#         "startTime": "2015-11-30T03:09Z",
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/9773/-1",
#         "note": "Associated with activity noted behind SW limb in 193 starting ~ 01:45Z.  Post eruption loops can be seen in STA EUVI on the SE (very close to the limb) around 06UT.",
#         "instruments": [
#             {
#                 "id": 5,
#                 "displayName": "STEREO A: SECCHI/COR2"
#             },
#             {
#                 "id": 1,
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "id": 2,
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "cmeAnalyses": [
#             {
#                 "time21_5": "2015-11-30T12:30Z",
#                 "latitude": -23.0,
#                 "longitude": 110.0,
#                 "halfAngle": 36.0,
#                 "speed": 455.0,
#                 "type": "S",
#                 "isMostAccurate": true,
#                 "note": "",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/9774/-1",
#                 "enlilList": [
#                     {
#                         "modelCompletionTime": "2015-11-30T18:30Z",
#                         "au": 2.0,
#                         "estimatedShockArrivalTime": null,
#                         "estimatedDuration": null,
#                         "rmin_re": null,
#                         "kp_18": null,
#                         "kp_90": null,
#                         "kp_135": null,
#                         "kp_180": null,
#                         "isEarthGB": false,
#                         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/WSA-ENLIL/9777/-1",
#                         "impactList": null,
#                         "cmeIDs": [
#                             "2015-11-30T03:09:00-CME-001"
#                         ]
#                     }
#                 ]
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2015-11-30T07:00:00-CME-001",
#         "catalog": "SWRC_CATALOG",
#         "startTime": "2015-11-30T07:00Z",
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/9778/-1",
#         "note": "Source location could not be accurately identified.  Longitude has been given by using STEREO_Cat with both SOHO and STA images.",
#         "instruments": [
#             {
#                 "id": 1,
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "id": 2,
#                 "displayName": "SOHO: LASCO/C3"
#             },
#             {
#                 "id": 5,
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "cmeAnalyses": [
#             {
#                 "time21_5": "2015-11-30T16:50Z",
#                 "latitude": 36.0,
#                 "longitude": -118.0,
#                 "halfAngle": 15.0,
#                 "speed": 389.0,
#                 "type": "S",
#                 "isMostAccurate": true,
#                 "note": "",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/9779/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     },
#     {
#         "activityID": "2015-12-01T09:54:00-CME-001",
#         "catalog": "SWRC_CATALOG",
#         "startTime": "2015-12-01T09:54Z",
#         "sourceLocation": "N10W42",
#         "activeRegionNum": 12458,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/9784/-1",
#         "note": "AIA:  A C3.6 flare, dimming and also some rising loops off-limb.",
#         "instruments": [
#             {
#                 "id": 5,
#                 "displayName": "STEREO A: SECCHI/COR2"
#             },
#             {
#                 "id": 1,
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "id": 2,
#                 "displayName": "SOHO: LASCO/C3"
#             }
#         ],
#         "cmeAnalyses": [
#             {
#                 "time21_5": "2015-12-01T12:48Z",
#                 "latitude": 11.0,
#                 "longitude": 103.0,
#                 "halfAngle": 27.0,
#                 "speed": 310.0,
#                 "type": "S",
#                 "isMostAccurate": true,
#                 "note": "This measurement is only plane-of-sky for STEREO-A.  No LASCO C2 or C3 data were used.",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/9785/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2015-12-01T07:59:00-FLR-001"
#             }
#         ]
#     },
#     {
#         "activityID": "2015-12-01T18:36:00-CME-001",
#         "catalog": "SWRC_CATALOG",
#         "startTime": "2015-12-01T18:36Z",
#         "sourceLocation": "",
#         "activeRegionNum": null,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CME/9787/-1",
#         "note": "Possibly associated with the earlier CME and flare at 2015-12-01T09:54Z.",
#         "instruments": [
#             {
#                 "id": 1,
#                 "displayName": "SOHO: LASCO/C2"
#             },
#             {
#                 "id": 5,
#                 "displayName": "STEREO A: SECCHI/COR2"
#             }
#         ],
#         "cmeAnalyses": [
#             {
#                 "time21_5": "2015-12-02T07:05Z",
#                 "latitude": 37.0,
#                 "longitude": 118.0,
#                 "halfAngle": 7.0,
#                 "speed": 320.0,
#                 "type": "S",
#                 "isMostAccurate": true,
#                 "note": "This measurement is plane of sky only for STEREO A, not using C2 or C3 data.",
#                 "levelOfData": 0,
#                 "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/CMEAnalysis/9788/-1",
#                 "enlilList": null
#             }
#         ],
#         "linkedEvents": null
#     }
# ]

# %% [markdown]
# # Geomagnetic Storm (GST)

# %% [markdown]
# ### Prepare API call

# %%
# Save config information
url2 = 'https://api.nasa.gov/DONKI/GST?startDate='

# Build partial query URL
query_url2 = f'{url2}{start_date}&endDate={end_date}&api_key={nasak}'

# %% [markdown]
# ### Make API call and format data

# %%
# make get query
try:
    response1 = requests.get(query_url2).json()
    print(json.dumps(response1, indent=4))
    
except ValueError:
    print("Date range selected has no results.")
# Out:
# [
#     {
#         "gstID": "2015-01-07T06:00:00-GST-001",
#         "startTime": "2015-01-07T06:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-01-07T09:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-01-07T12:00Z",
#                 "kpIndex": 7,
#                 "source": "NOAA"
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2015-01-07T05:24:00-IPS-001"
#             },
#             {
#                 "activityID": "2015-01-07T08:40:00-MPC-001"
#             }
#         ],
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GST/7537/-1"
#     },
#     {
#         "gstID": "2015-03-17T06:00:00-GST-001",
#         "startTime": "2015-03-17T06:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-03-17T09:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-03-17T12:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-03-17T15:00Z",
#                 "kpIndex": 8,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-03-17T18:00Z",
#                 "kpIndex": 8,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-03-17T21:00Z",
#                 "kpIndex": 7,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-03-18T00:00Z",
#                 "kpIndex": 8,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-03-18T03:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-03-18T18:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2015-03-15T02:00:00-CME-001"
#             },
#             {
#                 "activityID": "2015-03-17T04:05:00-IPS-001"
#             },
#             {
#                 "activityID": "2015-03-16T00:00:00-HSS-001"
#             }
#         ],
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GST/8031/-1"
#     },
#     {
#         "gstID": "2015-03-22T06:00:00-GST-001",
#         "startTime": "2015-03-22T06:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-03-22T09:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2015-03-21T20:25:00-IPS-001"
#             }
#         ],
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GST/8077/-1"
#     },
#     {
#         "gstID": "2015-04-10T03:00:00-GST-001",
#         "startTime": "2015-04-10T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-04-10T06:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-04-10T06:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-04-10T09:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             }
#         ],
#         "linkedEvents": null,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GST/8201/-1"
#     },
#     {
#         "gstID": "2015-04-16T21:00:00-GST-001",
#         "startTime": "2015-04-16T21:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-04-17T00:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             }
#         ],
#         "linkedEvents": null,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GST/8246/-1"
#     },
#     {
#         "gstID": "2015-05-13T03:00:00-GST-001",
#         "startTime": "2015-05-13T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-05-13T06:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-05-13T09:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2015-05-12T17:20:00-HSS-001"
#             }
#         ],
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GST/8487/-1"
#     },
#     {
#         "gstID": "2015-05-13T04:30:00-GST-001",
#         "startTime": "2015-05-13T04:30Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-05-13T09:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             }
#         ],
#         "linkedEvents": null,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GST/8489/-1"
#     },
#     {
#         "gstID": "2015-05-19T00:00:00-GST-001",
#         "startTime": "2015-05-19T00:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-05-19T03:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-05-19T03:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             }
#         ],
#         "linkedEvents": null,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GST/8521/-1"
#     },
#     {
#         "gstID": "2015-06-08T06:00:00-GST-001",
#         "startTime": "2015-06-08T06:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-06-08T09:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2015-06-08T00:16:00-HSS-001"
#             }
#         ],
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GST/8621/-1"
#     },
#     {
#         "gstID": "2015-06-22T18:00:00-GST-001",
#         "startTime": "2015-06-22T18:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-06-22T21:00Z",
#                 "kpIndex": 8,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-06-22T21:00Z",
#                 "kpIndex": 8,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-06-23T03:00Z",
#                 "kpIndex": 7,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-06-23T06:00Z",
#                 "kpIndex": 8,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-06-23T09:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-06-23T15:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2015-06-21T02:48:00-CME-001"
#             },
#             {
#                 "activityID": "2015-06-22T17:59:00-IPS-001"
#             }
#         ],
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GST/8763/-1"
#     },
#     {
#         "gstID": "2015-06-25T06:00:00-GST-001",
#         "startTime": "2015-06-25T06:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-06-25T09:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2015-06-22T18:36:00-CME-001"
#             },
#             {
#                 "activityID": "2015-06-24T12:57:00-IPS-001"
#             }
#         ],
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GST/8802/-1"
#     },
#     {
#         "gstID": "2015-07-04T13:00:00-GST-001",
#         "startTime": "2015-07-04T13:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-07-05T00:00Z",
#                 "kpIndex": 5,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-07-05T03:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-07-05T03:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2015-07-04T11:58:00-IPS-001"
#             },
#             {
#                 "activityID": "2015-07-04T11:59:00-HSS-001"
#             },
#             {
#                 "activityID": "2015-07-04T20:20:00-MPC-001"
#             }
#         ],
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GST/8862/-1"
#     },
#     {
#         "gstID": "2015-08-15T09:00:00-GST-001",
#         "startTime": "2015-08-15T09:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-08-15T12:00Z",
#                 "kpIndex": 7,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-08-15T15:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-08-16T09:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2015-08-12T15:12:00-CME-001"
#             },
#             {
#                 "activityID": "2015-08-13T00:30:00-CME-001"
#             },
#             {
#                 "activityID": "2015-08-15T07:43:00-IPS-001"
#             },
#             {
#                 "activityID": "2015-08-15T11:03:00-MPC-001"
#             }
#         ],
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GST/9113/-1"
#     },
#     {
#         "gstID": "2015-08-23T06:00:00-GST-001",
#         "startTime": "2015-08-23T06:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-08-23T09:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2015-08-23T07:15:00-HSS-001"
#             }
#         ],
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GST/9162/-1"
#     },
#     {
#         "gstID": "2015-08-27T03:00:00-GST-001",
#         "startTime": "2015-08-27T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-08-27T06:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-08-27T09:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             }
#         ],
#         "linkedEvents": null,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GST/9200/-1"
#     },
#     {
#         "gstID": "2015-08-27T21:00:00-GST-001",
#         "startTime": "2015-08-27T21:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-08-28T00:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-08-28T03:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             }
#         ],
#         "linkedEvents": null,
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GST/9210/-1"
#     },
#     {
#         "gstID": "2015-08-28T18:00:00-GST-001",
#         "startTime": "2015-08-28T18:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-08-28T21:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2015-08-28T16:00:00-HSS-001"
#             }
#         ],
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GST/9230/-1"
#     },
#     {
#         "gstID": "2015-09-07T15:00:00-GST-001",
#         "startTime": "2015-09-07T15:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-09-07T18:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-09-07T21:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-09-08T00:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-09-08T03:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-09-08T06:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2015-09-07T12:22:00-HSS-001"
#             },
#             {
#                 "activityID": "2015-09-07T13:20:00-IPS-001"
#             }
#         ],
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GST/9274/-1"
#     },
#     {
#         "gstID": "2015-09-09T03:00:00-GST-001",
#         "startTime": "2015-09-09T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-09-09T06:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-09-09T09:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-09-09T15:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-09-09T21:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-09-10T00:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2015-09-04T14:12:00-CME-001"
#             },
#             {
#                 "activityID": "2015-09-04T19:24:00-CME-001"
#             }
#         ],
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GST/9294/-1"
#     },
#     {
#         "gstID": "2015-09-11T06:00:00-GST-001",
#         "startTime": "2015-09-11T06:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-09-11T09:00Z",
#                 "kpIndex": 7,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-09-11T12:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-09-11T18:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2015-09-06T23:30:00-CME-001"
#             },
#             {
#                 "activityID": "2015-09-07T10:36:00-CME-001"
#             },
#             {
#                 "activityID": "2015-09-11T06:43:00-HSS-001"
#             }
#         ],
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GST/9302/-1"
#     },
#     {
#         "gstID": "2015-09-20T06:00:00-GST-001",
#         "startTime": "2015-09-20T06:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-09-20T09:00Z",
#                 "kpIndex": 7,
#                 "source": "NOAA"
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2015-09-18T05:00:00-CME-001"
#             },
#             {
#                 "activityID": "2015-09-20T05:33:00-IPS-001"
#             }
#         ],
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GST/9349/-1"
#     },
#     {
#         "gstID": "2015-09-20T09:00:00-GST-001",
#         "startTime": "2015-09-20T09:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-09-20T12:00Z",
#                 "kpIndex": 5,
#                 "source": "NOAA"
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2015-09-18T05:00:00-CME-001"
#             },
#             {
#                 "activityID": "2015-09-20T05:33:00-IPS-001"
#             }
#         ],
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GST/9352/-1"
#     },
#     {
#         "gstID": "2015-10-07T18:00:00-GST-001",
#         "startTime": "2015-10-07T18:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-10-07T06:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-10-07T09:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-10-07T18:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-10-07T21:00Z",
#                 "kpIndex": 7,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-10-07T21:00Z",
#                 "kpIndex": 7,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-10-08T00:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-10-08T06:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-10-08T09:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2015-10-07T13:00:00-HSS-001"
#             }
#         ],
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GST/9466/-1"
#     },
#     {
#         "gstID": "2015-11-07T03:00:00-GST-001",
#         "startTime": "2015-11-07T03:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-11-07T06:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             },
#             {
#                 "observedTime": "2015-11-07T09:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2015-11-04T14:24:00-CME-001"
#             },
#             {
#                 "activityID": "2015-11-06T17:34:00-IPS-001"
#             }
#         ],
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GST/9662/-1"
#     },
#     {
#         "gstID": "2015-11-10T12:00:00-GST-001",
#         "startTime": "2015-11-10T12:00Z",
#         "allKpIndex": [
#             {
#                 "observedTime": "2015-11-10T15:00Z",
#                 "kpIndex": 6,
#                 "source": "NOAA"
#             }
#         ],
#         "linkedEvents": [
#             {
#                 "activityID": "2015-11-09T19:00:00-HSS-001"
#             }
#         ],
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/GST/9682/-1"
#     }
# ]

# %% [markdown]
# # Interplanetary Shock (IPS)

# %% [markdown]
# ### Set up additional variables

# %%
# location: default to ALL (choices: Earth, MESSENGER, STEREO A, STEREO B)
# catalog: default to ALL (choices: SWRC_CATALOG, WINSLOW_MESSENGER_ICME_CATALOG)

bool1 = False

while bool1 == False:
    
    #enter location
    location = input("Enter a location (choices: Earth, MESSENGER, STEREO A, STEREO B): ").lower()
    
    if location == "earth" or location == "messenger" or location == "stereo a" or location == "stereo b":
        
        print(f'Location selected = {location}')
        bool1 = True
        
    else:
        print("Not a valid response, please select from the following options: Earth, MESSENGER, STEREO A, STEREO B")

while bool1 == True:
    
    #enter catalog
    catalog = input("Enter a catalog (choices: SWRC_CATALOG, WINSLOW_MESSENGER_ICME_CATALOG): ").lower()
    
    if catalog == "swrc_catalog" or catalog == "winslow_messenger_icme_catalog" :
        
        print(f'Catalog selected = {catalog}')
        bool1 = False
        
    else:
        print("Not a valid response, please select from the following options: SWRC_CATALOG, WINSLOW_MESSENGER_ICME_CATALOG")
# Out:
# Enter a location (choices: Earth, MESSENGER, STEREO A, STEREO B): earth
# Location selected = earth
# Enter a catalog (choices: SWRC_CATALOG, WINSLOW_MESSENGER_ICME_CATALOG): SWRC_CATALOG
# Catalog selected = swrc_catalog

# %% [markdown]
# ### Prepare API call

# %%
# Save config information
url3 = 'https://api.nasa.gov/DONKI/IPS?startDate='

# Build partial query URL
query_url3 = f'{url3}{start_date}&endDate={end_date}&location={location}&catalog={catalog}&api_key={nasak}'

# %% [markdown]
# ### Make API call and format data

# %%
# make get query
try:
    response2 = requests.get(query_url3).json()
    print(json.dumps(response2, indent=4))
    
except ValueError:
    print("Date range selected has no results.")
# Out:
# [
#     {
#         "catalog": "SWRC_CATALOG",
#         "activityID": "2015-01-07T05:24:00-IPS-001",
#         "location": "Earth",
#         "eventTime": "2015-01-07T05:24Z",
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/IPS/7542/-1",
#         "instruments": [
#             {
#                 "id": 10,
#                 "displayName": "ACE: MAG"
#             }
#         ]
#     },
#     {
#         "catalog": "SWRC_CATALOG",
#         "activityID": "2015-01-15T22:39:00-IPS-001",
#         "location": "Earth",
#         "eventTime": "2015-01-15T22:39Z",
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/IPS/7615/-1",
#         "instruments": [
#             {
#                 "id": 10,
#                 "displayName": "ACE: MAG"
#             },
#             {
#                 "id": 9,
#                 "displayName": "ACE: SWEPAM"
#             }
#         ]
#     },
#     {
#         "catalog": "SWRC_CATALOG",
#         "activityID": "2015-03-17T04:05:00-IPS-001",
#         "location": "Earth",
#         "eventTime": "2015-03-17T04:05Z",
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/IPS/8028/-1",
#         "instruments": [
#             {
#                 "id": 10,
#                 "displayName": "ACE: MAG"
#             },
#             {
#                 "id": 9,
#                 "displayName": "ACE: SWEPAM"
#             }
#         ]
#     },
#     {
#         "catalog": "SWRC_CATALOG",
#         "activityID": "2015-03-21T20:25:00-IPS-001",
#         "location": "Earth",
#         "eventTime": "2015-03-21T20:25Z",
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/IPS/8080/-1",
#         "instruments": [
#             {
#                 "id": 10,
#                 "displayName": "ACE: MAG"
#             },
#             {
#                 "id": 9,
#                 "displayName": "ACE: SWEPAM"
#             }
#         ]
#     },
#     {
#         "catalog": "SWRC_CATALOG",
#         "activityID": "2015-03-31T07:40:00-IPS-001",
#         "location": "Earth",
#         "eventTime": "2015-03-31T07:40Z",
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/IPS/8124/-1",
#         "instruments": [
#             {
#                 "id": 10,
#                 "displayName": "ACE: MAG"
#             },
#             {
#                 "id": 9,
#                 "displayName": "ACE: SWEPAM"
#             }
#         ]
#     },
#     {
#         "catalog": "SWRC_CATALOG",
#         "activityID": "2015-04-09T01:10:00-IPS-001",
#         "location": "Earth",
#         "eventTime": "2015-04-09T01:10Z",
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/IPS/8190/-1",
#         "instruments": [
#             {
#                 "id": 10,
#                 "displayName": "ACE: MAG"
#             },
#             {
#                 "id": 9,
#                 "displayName": "ACE: SWEPAM"
#             }
#         ]
#     },
#     {
#         "catalog": "SWRC_CATALOG",
#         "activityID": "2015-04-09T09:12:00-IPS-001",
#         "location": "Earth",
#         "eventTime": "2015-04-09T09:12Z",
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/IPS/8191/-1",
#         "instruments": [
#             {
#                 "id": 10,
#                 "displayName": "ACE: MAG"
#             },
#             {
#                 "id": 9,
#                 "displayName": "ACE: SWEPAM"
#             }
#         ]
#     },
#     {
#         "catalog": "SWRC_CATALOG",
#         "activityID": "2015-05-06T00:50:00-IPS-001",
#         "location": "Earth",
#         "eventTime": "2015-05-06T00:50Z",
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/IPS/8437/-1",
#         "instruments": [
#             {
#                 "id": 10,
#                 "displayName": "ACE: MAG"
#             },
#             {
#                 "id": 9,
#                 "displayName": "ACE: SWEPAM"
#             }
#         ]
#     },
#     {
#         "catalog": "SWRC_CATALOG",
#         "activityID": "2015-05-10T00:02:00-IPS-001",
#         "location": "Earth",
#         "eventTime": "2015-05-10T00:02Z",
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/IPS/8468/-1",
#         "instruments": [
#             {
#                 "id": 10,
#                 "displayName": "ACE: MAG"
#             },
#             {
#                 "id": 9,
#                 "displayName": "ACE: SWEPAM"
#             }
#         ]
#     },
#     {
#         "catalog": "SWRC_CATALOG",
#         "activityID": "2015-05-17T04:00:00-IPS-001",
#         "location": "Earth",
#         "eventTime": "2015-05-17T04:00Z",
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/IPS/8519/-1",
#         "instruments": [
#             {
#                 "id": 10,
#                 "displayName": "ACE: MAG"
#             },
#             {
#                 "id": 9,
#                 "displayName": "ACE: SWEPAM"
#             }
#         ]
#     },
#     {
#         "catalog": "SWRC_CATALOG",
#         "activityID": "2015-06-12T12:19:00-IPS-001",
#         "location": "Earth",
#         "eventTime": "2015-06-12T12:19Z",
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/IPS/8649/-1",
#         "instruments": [
#             {
#                 "id": 10,
#                 "displayName": "ACE: MAG"
#             },
#             {
#                 "id": 9,
#                 "displayName": "ACE: SWEPAM"
#             }
#         ]
#     },
#     {
#         "catalog": "SWRC_CATALOG",
#         "activityID": "2015-06-21T15:40:00-IPS-001",
#         "location": "Earth",
#         "eventTime": "2015-06-21T15:40Z",
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/IPS/8742/-1",
#         "instruments": [
#             {
#                 "id": 10,
#                 "displayName": "ACE: MAG"
#             },
#             {
#                 "id": 9,
#                 "displayName": "ACE: SWEPAM"
#             }
#         ]
#     },
#     {
#         "catalog": "SWRC_CATALOG",
#         "activityID": "2015-06-22T04:51:00-IPS-001",
#         "location": "Earth",
#         "eventTime": "2015-06-22T04:51Z",
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/IPS/8754/-1",
#         "instruments": [
#             {
#                 "id": 10,
#                 "displayName": "ACE: MAG"
#             },
#             {
#                 "id": 9,
#                 "displayName": "ACE: SWEPAM"
#             }
#         ]
#     },
#     {
#         "catalog": "SWRC_CATALOG",
#         "activityID": "2015-06-22T17:59:00-IPS-001",
#         "location": "Earth",
#         "eventTime": "2015-06-22T17:59Z",
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/IPS/8758/-1",
#         "instruments": [
#             {
#                 "id": 10,
#                 "displayName": "ACE: MAG"
#             },
#             {
#                 "id": 9,
#                 "displayName": "ACE: SWEPAM"
#             }
#         ]
#     },
#     {
#         "catalog": "SWRC_CATALOG",
#         "activityID": "2015-06-24T12:57:00-IPS-001",
#         "location": "Earth",
#         "eventTime": "2015-06-24T12:57Z",
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/IPS/8786/-1",
#         "instruments": [
#             {
#                 "id": 10,
#                 "displayName": "ACE: MAG"
#             },
#             {
#                 "id": 9,
#                 "displayName": "ACE: SWEPAM"
#             }
#         ]
#     },
#     {
#         "catalog": "SWRC_CATALOG",
#         "activityID": "2015-06-27T03:30:00-IPS-001",
#         "location": "Earth",
#         "eventTime": "2015-06-27T03:30Z",
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/IPS/8826/-1",
#         "instruments": [
#             {
#                 "id": 10,
#                 "displayName": "ACE: MAG"
#             },
#             {
#                 "id": 9,
#                 "displayName": "ACE: SWEPAM"
#             }
#         ]
#     },
#     {
#         "catalog": "SWRC_CATALOG",
#         "activityID": "2015-07-04T11:58:00-IPS-001",
#         "location": "Earth",
#         "eventTime": "2015-07-04T11:58Z",
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/IPS/8854/-1",
#         "instruments": [
#             {
#                 "id": 10,
#                 "displayName": "ACE: MAG"
#             },
#             {
#                 "id": 9,
#                 "displayName": "ACE: SWEPAM"
#             }
#         ]
#     },
#     {
#         "catalog": "SWRC_CATALOG",
#         "activityID": "2015-08-15T07:43:00-IPS-001",
#         "location": "Earth",
#         "eventTime": "2015-08-15T07:43Z",
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/IPS/9110/-1",
#         "instruments": [
#             {
#                 "id": 10,
#                 "displayName": "ACE: MAG"
#             },
#             {
#                 "id": 9,
#                 "displayName": "ACE: SWEPAM"
#             }
#         ]
#     },
#     {
#         "catalog": "SWRC_CATALOG",
#         "activityID": "2015-09-07T13:20:00-IPS-001",
#         "location": "Earth",
#         "eventTime": "2015-09-07T13:20Z",
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/IPS/9269/-1",
#         "instruments": [
#             {
#                 "id": 10,
#                 "displayName": "ACE: MAG"
#             },
#             {
#                 "id": 9,
#                 "displayName": "ACE: SWEPAM"
#             }
#         ]
#     },
#     {
#         "catalog": "SWRC_CATALOG",
#         "activityID": "2015-09-20T05:33:00-IPS-001",
#         "location": "Earth",
#         "eventTime": "2015-09-20T05:33Z",
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/IPS/9351/-1",
#         "instruments": [
#             {
#                 "id": 10,
#                 "displayName": "ACE: MAG"
#             },
#             {
#                 "id": 9,
#                 "displayName": "ACE: SWEPAM"
#             }
#         ]
#     },
#     {
#         "catalog": "SWRC_CATALOG",
#         "activityID": "2015-10-24T18:26:00-IPS-001",
#         "location": "Earth",
#         "eventTime": "2015-10-24T18:26Z",
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/IPS/9553/-1",
#         "instruments": [
#             {
#                 "id": 10,
#                 "displayName": "ACE: MAG"
#             },
#             {
#                 "id": 9,
#                 "displayName": "ACE: SWEPAM"
#             }
#         ]
#     },
#     {
#         "catalog": "SWRC_CATALOG",
#         "activityID": "2015-11-06T17:34:00-IPS-001",
#         "location": "Earth",
#         "eventTime": "2015-11-06T17:34Z",
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/IPS/9658/-1",
#         "instruments": [
#             {
#                 "id": 10,
#                 "displayName": "ACE: MAG"
#             },
#             {
#                 "id": 9,
#                 "displayName": "ACE: SWEPAM"
#             }
#         ]
#     },
#     {
#         "catalog": "SWRC_CATALOG",
#         "activityID": "2015-11-12T12:00:00-IPS-001",
#         "location": "Earth",
#         "eventTime": "2015-11-12T12:00Z",
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/IPS/9698/-1",
#         "instruments": [
#             {
#                 "id": 10,
#                 "displayName": "ACE: MAG"
#             },
#             {
#                 "id": 9,
#                 "displayName": "ACE: SWEPAM"
#             }
#         ]
#     },
#     {
#         "catalog": "SWRC_CATALOG",
#         "activityID": "2015-11-18T19:24:00-IPS-001",
#         "location": "Earth",
#         "eventTime": "2015-11-18T19:24Z",
#         "link": "https://kauai.ccmc.gsfc.nasa.gov/DONKI/view/IPS/9719/-1",
#         "instruments": [
#             {
#                 "id": 10,
#                 "displayName": "ACE: MAG"
#             },
#             {
#                 "id": 9,
#                 "displayName": "ACE: SWEPAM"
#             }
#         ]
#     }
# ]
